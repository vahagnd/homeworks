# %%
# !ls ../annotations/ | grep json
# Out:
# annotations_nightowls_coco.json
# few_shot_8_fair1m.json
# few_shot_visdrone.json
# few_shot_visdrone_val.json
# few_shot_visdrone_val_vis_drone_val_thresh_0.3_patch_16.json
# few_shot_visdrone_vis_drone_train_thresh_0.3_patch_16.json

# %%
import json

# %%
with open('../annotations/few_shot_visdrone_val.json') as f:
    data = json.load(f)

# %%
data
# Out:
# {'images': [{'file_name': '0000002_00005_d_0000014.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 0},
#   {'file_name': '0000010_00569_d_0000056.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 1},
#   {'file_name': '0000047_01000_d_0000090.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 2},
#   {'file_name': '0000068_00001_d_0000001.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 3},
#   {'file_name': '0000071_05298_d_0000008.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 4},
#   {'file_name': '0000072_05564_d_0000007.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 5},
#   {'file_name': '0000076_01012_d_0000004.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 6},
#   {'file_name': '0000076_04925_d_0000017.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 7},
#   {'file_name': '0000106_00673_d_0000050.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 8},
#   {'file_name': '0000109_00606_d_0000062.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 9},
#   {'file_name': '0000111_03678_d_0000072.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 10},
#   {'file_name': '0000122_01200_d_0000119.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 11},
#   {'file_name': '0000126_03828_d_0000129.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 12},
#   {'file_name': '0000134_00858_d_0000145.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 13},
#   {'file_name': '0000137_01824_d_0000162.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 14},
#   {'file_name': '0000141_01851_d_0000017.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 15},
#   {'file_name': '0000142_00258_d_0000024.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 16},
#   {'file_name': '0000142_02258_d_0000034.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 17},
#   {'file_name': '0000143_00081_d_0000048.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 18},
#   {'file_name': '0000144_04192_d_0000001.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 19},
#   {'file_name': '0000146_01601_d_0000065.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 20},
#   {'file_name': '0000150_01030_d_0000072.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 21},
#   {'file_name': '0000157_00251_d_0000081.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 22},
#   {'file_name': '0000165_03325_d_0000100.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 23},
#   {'file_name': '0000166_00158_d_0000116.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 24},
#   {'file_name': '0000167_01784_d_0000133.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 25},
#   {'file_name': '0000169_01098_d_0000001.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 26},
#   {'file_name': '0000171_00293_d_0000001.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 27},
#   {'file_name': '0000173_02401_d_0000001.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 28},
#   {'file_name': '0000176_00401_d_0000001.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 29},
#   {'file_name': '0000179_00445_d_0000016.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 30},
#   {'file_name': '0000180_00806_d_0000023.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 31},
#   {'file_name': '0000181_00387_d_0000029.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 32},
#   {'file_name': '0000182_01653_d_0000040.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 33},
#   {'file_name': '0000196_03560_d_0000142.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 34},
#   {'file_name': '0000198_00000_d_0000155.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 35},
#   {'file_name': '0000201_00000_d_0000171.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 36},
#   {'file_name': '0000204_01236_d_0000195.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 37},
#   {'file_name': '0000209_00609_d_0000221.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 38},
#   {'file_name': '0000214_01218_d_0000251.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 39},
#   {'file_name': '0000219_03118_d_0000007.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 40},
#   {'file_name': '0000220_04005_d_0000013.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 41},
#   {'file_name': '0000221_10787_d_0000008.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 42},
#   {'file_name': '0000222_02000_d_0000007.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 43},
#   {'file_name': '0000222_04900_d_0000016.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 44},
#   {'file_name': '0000224_00251_d_0000002.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 45},
#   {'file_name': '0000225_02427_d_0000009.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 46},
#   {'file_name': '0000226_01500_d_0000005.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 47},
#   {'file_name': '0000226_04291_d_0000016.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 48},
#   {'file_name': '0000228_01900_d_0000005.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 49},
#   {'file_name': '0000235_01411_d_0000004.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 50},
#   {'file_name': '0000239_04503_d_0000013.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 51},
#   {'file_name': '0000239_07930_d_0000021.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 52},
#   {'file_name': '0000239_13100_d_0000033.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 53},
#   {'file_name': '0000240_02531_d_0000007.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 54},
#   {'file_name': '0000247_00002_d_0000001.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 55},
#   {'file_name': '0000256_00001_d_0000014.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 56},
#   {'file_name': '0000256_01834_d_0000026.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 57},
#   {'file_name': '0000257_00249_d_0000043.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 58},
#   {'file_name': '0000257_01698_d_0000052.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 59},
#   {'file_name': '0000257_03482_d_0000059.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 60},
#   {'file_name': '0000258_00301_d_0000070.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 61},
#   {'file_name': '0000260_00001_d_0000103.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 62},
#   {'file_name': '0000260_02609_d_0000111.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 63},
#   {'file_name': '0000261_00601_d_0000122.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 64},
#   {'file_name': '0000261_04901_d_0000137.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 65},
#   {'file_name': '0000263_02601_d_0000180.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 66},
#   {'file_name': '0000264_01401_d_0000201.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 67},
#   {'file_name': '0000264_03201_d_0000210.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 68},
#   {'file_name': '0000270_03401_d_0000370.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 69},
#   {'file_name': '0000275_00001_d_0000497.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 70},
#   {'file_name': '0000279_00001_d_0000584.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 71},
#   {'file_name': '0000279_03001_d_0000598.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 72},
#   {'file_name': '0000281_02601_d_0000639.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 73},
#   {'file_name': '0000284_03801_d_0000691.jpg',
#    'height': 1080,
#    'width': 1920,
#    'id': 74},
#   {'file_name': '0000288_02001_d_0000794.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 75},
#   {'file_name': '0000288_05401_d_0000809.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 76},
#   {'file_name': '0000290_03001_d_0000862.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 77},
#   {'file_name': '0000300_00601_d_0000141.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 78},
#   {'file_name': '0000303_00001_d_0000183.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 79},
#   {'file_name': '0000303_02801_d_0000197.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 80},
#   {'file_name': '0000305_00401_d_0000215.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 81},
#   {'file_name': '0000305_01801_d_0000222.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 82},
#   {'file_name': '0000308_00801_d_0000309.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 83},
#   {'file_name': '0000309_00201_d_0000334.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 84},
#   {'file_name': '0000309_02601_d_0000346.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 85},
#   {'file_name': '0000313_00001_d_0000436.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 86},
#   {'file_name': '0000313_06001_d_0000466.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 87},
#   {'file_name': '0000318_03401_d_0000571.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 88},
#   {'file_name': '0000323_02801_d_0000646.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 89},
#   {'file_name': '0000325_03001_d_0000677.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 90},
#   {'file_name': '0000325_06601_d_0000695.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 91},
#   {'file_name': '0000329_03601_d_0000783.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 92},
#   {'file_name': '0000331_00201_d_0000825.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 93},
#   {'file_name': '0000331_04601_d_0000864.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 94},
#   {'file_name': '0000334_01569_d_0000029.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 95},
#   {'file_name': '0000334_03333_d_0000038.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 96},
#   {'file_name': '0000338_01177_d_0000144.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 97},
#   {'file_name': '0000338_04313_d_0000160.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 98},
#   {'file_name': '0000339_01765_d_0000170.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 99},
#   {'file_name': '0000342_02353_d_0000254.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 100},
#   {'file_name': '0000342_04313_d_0000264.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 101},
#   {'file_name': '0000342_06273_d_0000274.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 102},
#   {'file_name': '0000344_01961_d_0000303.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 103},
#   {'file_name': '0000345_01373_d_0000316.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 104},
#   {'file_name': '0000348_02941_d_0000421.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 105},
#   {'file_name': '0000348_06469_d_0000439.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 106},
#   {'file_name': '0000349_06077_d_0000471.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 107},
#   {'file_name': '0000351_02157_d_0000530.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 108},
#   {'file_name': '0000352_02157_d_0000550.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 109},
#   {'file_name': '0000352_03529_d_0000557.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 110},
#   {'file_name': '0000352_05097_d_0000565.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 111},
#   {'file_name': '0000358_01177_d_0000686.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 112},
#   {'file_name': '0000363_00785_d_0000787.jpg',
#    'height': 540,
#    'width': 960,
#    'id': 113},
#   {'file_name': '0000366_01569_d_0000790.jpg',
#    'height': 765,
#    'width': 1360,
#    'id': 114},
#   {'file_name': '9999937_00000_d_0000005.jpg',
#    'height': 756,
#    'width': 1344,
#    'id': 115},
#   {'file_name': '9999937_00000_d_0000014.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 116},
#   {'file_name': '9999937_00000_d_0000034.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 117},
#   {'file_name': '9999937_00000_d_0000041.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 118},
#   {'file_name': '9999937_00000_d_0000051.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 119},
#   {'file_name': '9999937_00000_d_0000061.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 120},
#   {'file_name': '9999937_00000_d_0000074.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 121},
#   {'file_name': '9999937_00000_d_0000087.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 122},
#   {'file_name': '9999937_00000_d_0000094.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 123},
#   {'file_name': '9999937_00000_d_0000103.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 124},
#   {'file_name': '9999937_00000_d_0000113.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 125},
#   {'file_name': '9999937_00000_d_0000122.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 126},
#   {'file_name': '9999937_00000_d_0000128.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 127},
#   {'file_name': '9999937_00000_d_0000135.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 128},
#   {'file_name': '9999937_00000_d_0000145.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 129},
#   {'file_name': '9999937_00000_d_0000156.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 130},
#   {'file_name': '9999937_00000_d_0000171.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 131},
#   {'file_name': '9999937_00000_d_0000180.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 132},
#   {'file_name': '9999937_00000_d_0000204.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 133},
#   {'file_name': '9999937_00000_d_0000219.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 134},
#   {'file_name': '9999940_00000_d_0000008.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 135},
#   {'file_name': '9999940_00000_d_0000017.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 136},
#   {'file_name': '9999940_00000_d_0000030.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 137},
#   {'file_name': '9999940_00000_d_0000042.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 138},
#   {'file_name': '9999940_00000_d_0000054.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 139},
#   {'file_name': '9999940_00000_d_0000065.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 140},
#   {'file_name': '9999940_00000_d_0000079.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 141},
#   {'file_name': '9999940_00000_d_0000087.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 142},
#   {'file_name': '9999940_00000_d_0000098.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 143},
#   {'file_name': '9999942_00000_d_0000007.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 144},
#   {'file_name': '9999942_00000_d_0000021.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 145},
#   {'file_name': '9999942_00000_d_0000031.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 146},
#   {'file_name': '9999942_00000_d_0000038.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 147},
#   {'file_name': '9999942_00000_d_0000046.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 148},
#   {'file_name': '9999942_00000_d_0000056.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 149},
#   {'file_name': '9999942_00000_d_0000065.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 150},
#   {'file_name': '9999942_00000_d_0000073.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 151},
#   {'file_name': '9999942_00000_d_0000085.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 152},
#   {'file_name': '9999942_00000_d_0000094.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 153},
#   {'file_name': '9999942_00000_d_0000102.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 154},
#   {'file_name': '9999942_00000_d_0000114.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 155},
#   {'file_name': '9999942_00000_d_0000122.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 156},
#   {'file_name': '9999942_00000_d_0000139.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 157},
#   {'file_name': '9999942_00000_d_0000151.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 158},
#   {'file_name': '9999942_00000_d_0000165.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 159},
#   {'file_name': '9999942_00000_d_0000183.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 160},
#   {'file_name': '9999942_00000_d_0000196.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 161},
#   {'file_name': '9999942_00000_d_0000205.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 162},
#   {'file_name': '9999942_00000_d_0000219.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 163},
#   {'file_name': '9999942_00000_d_0000230.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 164},
#   {'file_name': '9999942_00000_d_0000241.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 165},
#   {'file_name': '9999942_00000_d_0000257.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 166},
#   {'file_name': '9999942_00000_d_0000268.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 167},
#   {'file_name': '9999943_00000_d_0000006.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 168},
#   {'file_name': '9999943_00000_d_0000023.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 169},
#   {'file_name': '9999943_00000_d_0000036.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 170},
#   {'file_name': '9999943_00000_d_0000041.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 171},
#   {'file_name': '9999943_00000_d_0000052.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 172},
#   {'file_name': '9999943_00000_d_0000062.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 173},
#   {'file_name': '9999943_00000_d_0000072.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 174},
#   {'file_name': '9999943_00000_d_0000081.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 175},
#   {'file_name': '9999945_00000_d_0000002.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 176},
#   {'file_name': '9999945_00000_d_0000017.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 177},
#   {'file_name': '9999945_00000_d_0000028.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 178},
#   {'file_name': '9999945_00000_d_0000036.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 179},
#   {'file_name': '9999945_00000_d_0000046.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 180},
#   {'file_name': '9999945_00000_d_0000058.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 181},
#   {'file_name': '9999945_00000_d_0000076.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 182},
#   {'file_name': '9999945_00000_d_0000093.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 183},
#   {'file_name': '9999945_00000_d_0000104.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 184},
#   {'file_name': '9999945_00000_d_0000120.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 185},
#   {'file_name': '9999945_00000_d_0000129.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 186},
#   {'file_name': '9999945_00000_d_0000146.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 187},
#   {'file_name': '9999945_00000_d_0000163.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 188},
#   {'file_name': '9999945_00000_d_0000175.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 189},
#   {'file_name': '9999948_00000_d_0000005.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 190},
#   {'file_name': '9999948_00000_d_0000017.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 191},
#   {'file_name': '9999948_00000_d_0000025.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 192},
#   {'file_name': '9999948_00000_d_0000038.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 193},
#   {'file_name': '9999950_00000_d_0000006.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 194},
#   {'file_name': '9999950_00000_d_0000025.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 195},
#   {'file_name': '9999950_00000_d_0000036.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 196},
#   {'file_name': '9999950_00000_d_0000043.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 197},
#   {'file_name': '9999950_00000_d_0000051.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 198},
#   {'file_name': '9999950_00000_d_0000063.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 199},
#   {'file_name': '9999950_00000_d_0000069.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 200},
#   {'file_name': '9999950_00000_d_0000074.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 201},
#   {'file_name': '9999950_00000_d_10000080.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 202},
#   {'file_name': '9999951_00000_d_0000024.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 203},
#   {'file_name': '9999951_00000_d_0000035.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 204},
#   {'file_name': '9999951_00000_d_0000049.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 205},
#   {'file_name': '9999951_00000_d_0000057.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 206},
#   {'file_name': '9999951_00000_d_0000069.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 207},
#   {'file_name': '9999951_00000_d_0000081.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 208},
#   {'file_name': '9999951_00000_d_0000090.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 209},
#   {'file_name': '9999951_00000_d_0000096.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 210},
#   {'file_name': '9999951_00000_d_0000107.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 211},
#   {'file_name': '9999951_00000_d_0000117.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 212},
#   {'file_name': '9999951_00000_d_0000126.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 213},
#   {'file_name': '9999951_00000_d_0000138.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 214},
#   {'file_name': '9999951_00000_d_0000147.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 215},
#   {'file_name': '9999951_00000_d_0000152.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 216},
#   {'file_name': '9999951_00000_d_0000165.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 217},
#   {'file_name': '9999951_00000_d_0000175.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 218},
#   {'file_name': '9999951_00000_d_0000185.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 219},
#   {'file_name': '9999951_00000_d_0000203.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 220},
#   {'file_name': '9999951_00000_d_0000220.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 221},
#   {'file_name': '9999951_00000_d_0000231.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 222},
#   {'file_name': '9999951_00000_d_0000237.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 223},
#   {'file_name': '9999951_00000_d_0000254.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 224},
#   {'file_name': '9999951_00000_d_0000262.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 225},
#   {'file_name': '9999951_00000_d_0000272.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 226},
#   {'file_name': '9999951_00000_d_0000284.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 227},
#   {'file_name': '9999951_00000_d_0000295.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 228},
#   {'file_name': '9999951_00000_d_0000307.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 229},
#   {'file_name': '9999951_00000_d_0000323.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 230},
#   {'file_name': '9999953_00000_d_0000002.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 231},
#   {'file_name': '9999953_00000_d_0000013.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 232},
#   {'file_name': '9999953_00000_d_0000030.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 233},
#   {'file_name': '9999953_00000_d_0000039.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 234},
#   {'file_name': '9999953_00000_d_0000063.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 235},
#   {'file_name': '9999953_00000_d_0000074.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 236},
#   {'file_name': '9999953_00000_d_0000085.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 237},
#   {'file_name': '9999953_00000_d_0000094.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 238},
#   {'file_name': '9999953_00000_d_0000106.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 239},
#   {'file_name': '9999953_00000_d_0000115.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 240},
#   {'file_name': '9999953_00000_d_0000130.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 241},
#   {'file_name': '9999953_00000_d_0000138.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 242},
#   {'file_name': '9999953_00000_d_0000156.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 243},
#   {'file_name': '9999953_00000_d_0000165.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 244},
#   {'file_name': '9999953_00000_d_0000176.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 245},
#   {'file_name': '9999953_00000_d_0000187.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 246},
#   {'file_name': '9999953_00000_d_0000207.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 247},
#   {'file_name': '9999953_00000_d_0000213.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 248},
#   {'file_name': '9999953_00000_d_0000223.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 249},
#   {'file_name': '9999955_00000_d_0000001.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 250},
#   {'file_name': '9999955_00000_d_0000008.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 251},
#   {'file_name': '9999955_00000_d_0000013.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 252},
#   {'file_name': '9999955_00000_d_0000021.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 253},
#   {'file_name': '9999955_00000_d_0000042.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 254},
#   {'file_name': '9999955_00000_d_0000054.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 255},
#   {'file_name': '9999955_00000_d_0000068.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 256},
#   {'file_name': '9999955_00000_d_0000077.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 257},
#   {'file_name': '9999955_00000_d_0000084.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 258},
#   {'file_name': '9999955_00000_d_0000097.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 259},
#   {'file_name': '9999955_00000_d_0000103.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 260},
#   {'file_name': '9999955_00000_d_0000109.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 261},
#   {'file_name': '9999955_00000_d_0000119.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 262},
#   {'file_name': '9999955_00000_d_0000129.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 263},
#   {'file_name': '9999955_00000_d_0000139.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 264},
#   {'file_name': '9999955_00000_d_0000147.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 265},
#   {'file_name': '9999955_00000_d_0000166.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 266},
#   {'file_name': '9999955_00000_d_0000174.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 267},
#   {'file_name': '9999955_00000_d_0000183.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 268},
#   {'file_name': '9999955_00000_d_0000193.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 269},
#   {'file_name': '9999955_00000_d_0000201.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 270},
#   {'file_name': '9999955_00000_d_0000212.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 271},
#   {'file_name': '9999955_00000_d_0000236.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 272},
#   {'file_name': '9999955_00000_d_0000251.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 273},
#   {'file_name': '9999955_00000_d_0000281.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 274},
#   {'file_name': '9999955_00000_d_0000297.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 275},
#   {'file_name': '9999955_00000_d_0000305.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 276},
#   {'file_name': '9999955_00000_d_0000314.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 277},
#   {'file_name': '9999955_00000_d_0000327.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 278},
#   {'file_name': '9999955_00000_d_0000333.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 279},
#   {'file_name': '9999955_00000_d_0000340.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 280},
#   {'file_name': '9999955_00000_d_0000349.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 281},
#   {'file_name': '9999955_00000_d_0000360.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 282},
#   {'file_name': '9999955_00000_d_0000371.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 283},
#   {'file_name': '9999955_00000_d_0000378.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 284},
#   {'file_name': '9999955_00000_d_0000386.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 285},
#   {'file_name': '9999955_00000_d_0000394.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 286},
#   {'file_name': '9999955_00000_d_0000405.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 287},
#   {'file_name': '9999955_00000_d_0000415.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 288},
#   {'file_name': '9999955_00000_d_0000433.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 289},
#   {'file_name': '9999956_00000_d_0000016.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 290},
#   {'file_name': '9999956_00000_d_0000025.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 291},
#   {'file_name': '9999956_00000_d_0000038.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 292},
#   {'file_name': '9999956_00000_d_0000045.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 293},
#   {'file_name': '9999956_00000_d_0000063.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 294},
#   {'file_name': '9999956_00000_d_0000076.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 295},
#   {'file_name': '9999956_00000_d_0000085.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 296},
#   {'file_name': '9999956_00000_d_0000096.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 297},
#   {'file_name': '9999956_00000_d_0000101.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 298},
#   {'file_name': '9999956_00000_d_0000114.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 299},
#   {'file_name': '9999960_00000_d_0000004.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 300},
#   {'file_name': '9999960_00000_d_0000010.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 301},
#   {'file_name': '9999960_00000_d_0000031.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 302},
#   {'file_name': '9999960_00000_d_0000043.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 303},
#   {'file_name': '9999960_00000_d_0000061.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 304},
#   {'file_name': '9999960_00000_d_0000075.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 305},
#   {'file_name': '9999960_00000_d_0000080.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 306},
#   {'file_name': '9999960_00000_d_0000091.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 307},
#   {'file_name': '9999960_00000_d_0000098.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 308},
#   {'file_name': '9999960_00000_d_0000109.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 309},
#   {'file_name': '9999960_00000_d_0000128.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 310},
#   {'file_name': '9999960_00000_d_0000140.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 311},
#   {'file_name': '9999960_00000_d_0000147.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 312},
#   {'file_name': '9999960_00000_d_0000155.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 313},
#   {'file_name': '9999960_00000_d_0000162.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 314},
#   {'file_name': '9999960_00000_d_0000171.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 315},
#   {'file_name': '9999960_00000_d_0000176.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 316},
#   {'file_name': '9999960_00000_d_0000183.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 317},
#   {'file_name': '9999962_00000_d_0000018.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 318},
#   {'file_name': '9999962_00000_d_0000028.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 319},
#   {'file_name': '9999962_00000_d_0000043.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 320},
#   {'file_name': '9999962_00000_d_0000050.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 321},
#   {'file_name': '9999962_00000_d_0000065.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 322},
#   {'file_name': '9999962_00000_d_0000073.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 323},
#   {'file_name': '9999962_00000_d_0000086.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 324},
#   {'file_name': '9999962_00000_d_0000105.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 325},
#   {'file_name': '9999962_00000_d_0000111.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 326},
#   {'file_name': '9999962_00000_d_0000119.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 327},
#   {'file_name': '9999962_00000_d_0000130.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 328},
#   {'file_name': '9999962_00000_d_0000156.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 329},
#   {'file_name': '9999964_00000_d_0000002.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 330},
#   {'file_name': '9999964_00000_d_0000015.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 331},
#   {'file_name': '9999964_00000_d_0000026.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 332},
#   {'file_name': '9999964_00000_d_0000037.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 333},
#   {'file_name': '9999964_00000_d_0000045.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 334},
#   {'file_name': '9999964_00000_d_0000054.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 335},
#   {'file_name': '9999964_00000_d_0000063.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 336},
#   {'file_name': '9999964_00000_d_0000074.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 337},
#   {'file_name': '9999965_00000_d_0000005.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 338},
#   {'file_name': '9999965_00000_d_0000018.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 339},
#   {'file_name': '9999965_00000_d_0000029.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 340},
#   {'file_name': '9999965_00000_d_0000035.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 341},
#   {'file_name': '9999965_00000_d_0000046.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 342},
#   {'file_name': '9999965_00000_d_0000052.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 343},
#   {'file_name': '9999965_00000_d_0000065.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 344},
#   {'file_name': '9999965_00000_d_0000072.jpg',
#    'height': 788,
#    'width': 1400,
#    'id': 345},
#   {'file_name': '9999966_00000_d_0000030.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 346},
#   {'file_name': '9999966_00000_d_0000040.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 347},
#   {'file_name': '9999966_00000_d_0000052.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 348},
#   {'file_name': '9999966_00000_d_0000077.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 349},
#   {'file_name': '9999966_00000_d_0000100.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 350},
#   {'file_name': '9999966_00000_d_0000116.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 351},
#   {'file_name': '9999966_00000_d_0000126.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 352},
#   {'file_name': '9999967_00000_d_0000018.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 353},
#   {'file_name': '9999967_00000_d_0000025.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 354},
#   {'file_name': '9999967_00000_d_0000041.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 355},
#   {'file_name': '9999967_00000_d_0000050.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 356},
#   {'file_name': '9999967_00000_d_0000065.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 357},
#   {'file_name': '9999969_00000_d_0000010.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 358},
#   {'file_name': '9999969_00000_d_0000018.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 359},
#   {'file_name': '9999969_00000_d_0000032.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 360},
#   {'file_name': '9999969_00000_d_0000040.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 361},
#   {'file_name': '9999969_00000_d_0000051.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 362},
#   {'file_name': '9999969_00000_d_0000070.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 363},
#   {'file_name': '9999970_00000_d_0000011.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 364},
#   {'file_name': '9999970_00000_d_0000026.jpg',
#    'height': 1048,
#    'width': 1398,
#    'id': 365},
#   {'file_name': '9999970_00000_d_0000035.jpg',
#    'height': 1048,
#    'width': 1398,
#    'id': 366},
#   {'file_name': '9999972_00000_d_0000002.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 367},
#   {'file_name': '9999972_00000_d_0000014.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 368},
#   {'file_name': '9999972_00000_d_0000021.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 369},
#   {'file_name': '9999972_00000_d_0000034.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 370},
#   {'file_name': '9999972_00000_d_0000051.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 371},
#   {'file_name': '9999972_00000_d_0000059.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 372},
#   {'file_name': '9999972_00000_d_0000067.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 373},
#   {'file_name': '9999972_00000_d_0000085.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 374},
#   {'file_name': '9999972_00000_d_0000093.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 375},
#   {'file_name': '9999972_00000_d_0000104.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 376},
#   {'file_name': '9999972_00000_d_0000111.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 377},
#   {'file_name': '9999972_00000_d_0000119.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 378},
#   {'file_name': '9999972_00000_d_0000126.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 379},
#   {'file_name': '9999972_00000_d_0000135.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 380},
#   {'file_name': '9999972_00000_d_0000145.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 381},
#   {'file_name': '9999972_00000_d_0000161.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 382},
#   {'file_name': '9999974_00000_d_0000009.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 383},
#   {'file_name': '9999974_00000_d_0000022.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 384},
#   {'file_name': '9999974_00000_d_0000029.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 385},
#   {'file_name': '9999974_00000_d_0000038.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 386},
#   {'file_name': '9999974_00000_d_0000048.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 387},
#   {'file_name': '9999974_00000_d_0000057.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 388},
#   {'file_name': '9999975_00000_d_0000010.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 389},
#   {'file_name': '9999975_00000_d_0000019.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 390},
#   {'file_name': '9999977_00000_d_0000007.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 391},
#   {'file_name': '9999977_00000_d_0000015.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 392},
#   {'file_name': '9999977_00000_d_0000022.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 393},
#   {'file_name': '9999977_00000_d_0000031.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 394},
#   {'file_name': '9999977_00000_d_0000041.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 395},
#   {'file_name': '9999977_00000_d_0000049.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 396},
#   {'file_name': '9999977_00000_d_0000055.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 397},
#   {'file_name': '9999977_00000_d_0000066.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 398},
#   {'file_name': '9999977_00000_d_0000080.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 399},
#   {'file_name': '9999977_00000_d_0000085.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 400},
#   {'file_name': '9999977_00000_d_0000095.jpg',
#    'height': 1078,
#    'width': 1916,
#    'id': 401},
#   {'file_name': '9999981_00000_d_0000003.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 402},
#   {'file_name': '9999981_00000_d_0000015.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 403},
#   {'file_name': '9999981_00000_d_0000028.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 404},
#   {'file_name': '9999981_00000_d_0000039.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 405},
#   {'file_name': '9999981_00000_d_0000060.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 406},
#   {'file_name': '9999981_00000_d_0000070.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 407},
#   {'file_name': '9999981_00000_d_0000088.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 408},
#   {'file_name': '9999981_00000_d_0000105.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 409},
#   {'file_name': '9999981_00000_d_0000114.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 410},
#   {'file_name': '9999981_00000_d_0000120.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 411},
#   {'file_name': '9999981_00000_d_0000139.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 412},
#   {'file_name': '9999981_00000_d_0000149.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 413},
#   {'file_name': '9999982_00000_d_0000004.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 414},
#   {'file_name': '9999982_00000_d_0000010.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 415},
#   {'file_name': '9999982_00000_d_0000023.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 416},
#   {'file_name': '9999982_00000_d_0000045.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 417},
#   {'file_name': '9999982_00000_d_0000060.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 418},
#   {'file_name': '9999982_00000_d_0000067.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 419},
#   {'file_name': '9999982_00000_d_0000075.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 420},
#   {'file_name': '9999982_00000_d_0000089.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 421},
#   {'file_name': '9999982_00000_d_0000099.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 422},
#   {'file_name': '9999982_00000_d_0000110.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 423},
#   {'file_name': '9999982_00000_d_0000122.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 424},
#   {'file_name': '9999982_00000_d_0000131.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 425},
#   {'file_name': '9999982_00000_d_0000139.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 426},
#   {'file_name': '9999982_00000_d_0000156.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 427},
#   {'file_name': '9999982_00000_d_0000164.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 428},
#   {'file_name': '9999982_00000_d_0000177.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 429},
#   {'file_name': '9999982_00000_d_0000185.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 430},
#   {'file_name': '9999982_00000_d_0000195.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 431},
#   {'file_name': '9999982_00000_d_0000205.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 432},
#   {'file_name': '9999982_00000_d_0000213.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 433},
#   {'file_name': '9999982_00000_d_0000222.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 434},
#   {'file_name': '9999982_00000_d_0000229.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 435},
#   {'file_name': '9999982_00000_d_0000239.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 436},
#   {'file_name': '9999982_00000_d_0000254.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 437},
#   {'file_name': '9999984_00000_d_0000010.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 438},
#   {'file_name': '9999984_00000_d_0000024.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 439},
#   {'file_name': '9999984_00000_d_0000039.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 440},
#   {'file_name': '9999984_00000_d_0000048.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 441},
#   {'file_name': '9999984_00000_d_0000054.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 442},
#   {'file_name': '9999984_00000_d_0000062.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 443},
#   {'file_name': '9999984_00000_d_0000074.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 444},
#   {'file_name': '9999984_00000_d_0000108.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 445},
#   {'file_name': '9999984_00000_d_0000115.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 446},
#   {'file_name': '9999984_00000_d_0000125.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 447},
#   {'file_name': '9999984_00000_d_0000138.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 448},
#   {'file_name': '9999984_00000_d_0000147.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 449},
#   {'file_name': '9999984_00000_d_0000157.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 450},
#   {'file_name': '9999984_00000_d_0000164.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 451},
#   {'file_name': '9999984_00000_d_0000174.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 452},
#   {'file_name': '9999985_00000_d_0000010.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 453},
#   {'file_name': '9999985_00000_d_0000015.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 454},
#   {'file_name': '9999985_00000_d_0000025.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 455},
#   {'file_name': '9999985_00000_d_0000033.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 456},
#   {'file_name': '9999985_00000_d_0000044.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 457},
#   {'file_name': '9999985_00000_d_0000052.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 458},
#   {'file_name': '9999985_00000_d_0000065.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 459},
#   {'file_name': '9999985_00000_d_0000074.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 460},
#   {'file_name': '9999987_00000_d_0000030.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 461},
#   {'file_name': '9999987_00000_d_0000062.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 462},
#   {'file_name': '9999989_00000_d_0000012.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 463},
#   {'file_name': '9999990_00000_d_0000007.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 464},
#   {'file_name': '9999990_00000_d_0000018.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 465},
#   {'file_name': '9999990_00000_d_0000031.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 466},
#   {'file_name': '9999990_00000_d_0000039.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 467},
#   {'file_name': '9999990_00000_d_0000059.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 468},
#   {'file_name': '9999990_00000_d_0000067.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 469},
#   {'file_name': '9999990_00000_d_0000079.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 470},
#   {'file_name': '9999991_00000_d_0000014.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 471},
#   {'file_name': '9999991_00000_d_0000022.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 472},
#   {'file_name': '9999991_00000_d_0000035.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 473},
#   {'file_name': '9999994_00000_d_0000006.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 474},
#   {'file_name': '9999994_00000_d_0000018.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 475},
#   {'file_name': '9999994_00000_d_0000031.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 476},
#   {'file_name': '9999994_00000_d_0000038.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 477},
#   {'file_name': '9999994_00000_d_0000057.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 478},
#   {'file_name': '9999994_00000_d_0000073.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 479},
#   {'file_name': '9999994_00000_d_0000084.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 480},
#   {'file_name': '9999994_00000_d_0000100.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 481},
#   {'file_name': '9999994_00000_d_0000114.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 482},
#   {'file_name': '9999997_00000_d_0000008.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 483},
#   {'file_name': '9999997_00000_d_0000020.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 484},
#   {'file_name': '9999997_00000_d_0000040.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 485},
#   {'file_name': '9999997_00000_d_0000054.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 486},
#   {'file_name': '9999997_00000_d_0000067.jpg',
#    'height': 1050,
#    'width': 1400,
#    'id': 487},
# ...
#    'area': 7520},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [823, 572, 75, 75],
#    'id': 10,
#    'iscrowd': 0,
#    'area': 5625},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [740, 472, 58, 44],
#    'id': 11,
#    'iscrowd': 0,
#    'area': 2552},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [906, 591, 97, 70],
#    'id': 12,
#    'iscrowd': 0,
#    'area': 6790},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1002, 566, 67, 77],
#    'id': 13,
#    'iscrowd': 0,
#    'area': 5159},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1013, 506, 52, 47],
#    'id': 14,
#    'iscrowd': 0,
#    'area': 2444},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1660, 752, 216, 107],
#    'id': 15,
#    'iscrowd': 0,
#    'area': 23112},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1429, 690, 165, 97],
#    'id': 16,
#    'iscrowd': 0,
#    'area': 16005},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1539, 675, 175, 76],
#    'id': 17,
#    'iscrowd': 0,
#    'area': 13300},
#   {'image_id': 45,
#    'category_id': 10,
#    'bbox': [1317, 621, 133, 74],
#    'id': 18,
#    'iscrowd': 0,
#    'area': 9842},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1109, 595, 148, 63],
#    'id': 19,
#    'iscrowd': 0,
#    'area': 9324},
#   {'image_id': 45,
#    'category_id': 1,
#    'bbox': [1220, 585, 33, 39],
#    'id': 20,
#    'iscrowd': 0,
#    'area': 1287},
#   {'image_id': 45,
#    'category_id': 6,
#    'bbox': [1199, 605, 62, 42],
#    'id': 21,
#    'iscrowd': 0,
#    'area': 2604},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [879, 522, 94, 85],
#    'id': 22,
#    'iscrowd': 0,
#    'area': 7990},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [844, 497, 50, 57],
#    'id': 23,
#    'iscrowd': 0,
#    'area': 2850},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [813, 466, 40, 46],
#    'id': 24,
#    'iscrowd': 0,
#    'area': 1840},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [982, 440, 48, 42],
#    'id': 25,
#    'iscrowd': 0,
#    'area': 2016},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [663, 423, 75, 47],
#    'id': 26,
#    'iscrowd': 0,
#    'area': 3525},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [737, 416, 49, 37],
#    'id': 27,
#    'iscrowd': 0,
#    'area': 1813},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [858, 432, 43, 38],
#    'id': 28,
#    'iscrowd': 0,
#    'area': 1634},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [813, 409, 42, 33],
#    'id': 29,
#    'iscrowd': 0,
#    'area': 1386},
#   {'image_id': 45,
#    'category_id': 1,
#    'bbox': [738, 383, 11, 18],
#    'id': 30,
#    'iscrowd': 0,
#    'area': 198},
#   {'image_id': 45,
#    'category_id': 8,
#    'bbox': [733, 391, 24, 20],
#    'id': 31,
#    'iscrowd': 0,
#    'area': 480},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [783, 386, 39, 34],
#    'id': 32,
#    'iscrowd': 0,
#    'area': 1326},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [891, 393, 38, 35],
#    'id': 33,
#    'iscrowd': 0,
#    'area': 1330},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [841, 379, 36, 38],
#    'id': 34,
#    'iscrowd': 0,
#    'area': 1368},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [863, 364, 33, 35],
#    'id': 35,
#    'iscrowd': 0,
#    'area': 1155},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1041, 425, 44, 36],
#    'id': 36,
#    'iscrowd': 0,
#    'area': 1584},
#   {'image_id': 45,
#    'category_id': 11,
#    'bbox': [1027, 371, 42, 52],
#    'id': 37,
#    'iscrowd': 0,
#    'area': 2184},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [924, 355, 38, 31],
#    'id': 38,
#    'iscrowd': 0,
#    'area': 1178},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1063, 347, 32, 28],
#    'id': 39,
#    'iscrowd': 0,
#    'area': 896},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1069, 325, 34, 25],
#    'id': 40,
#    'iscrowd': 0,
#    'area': 850},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [897, 341, 30, 27],
#    'id': 41,
#    'iscrowd': 0,
#    'area': 810},
#   {'image_id': 45,
#    'category_id': 10,
#    'bbox': [922, 326, 30, 30],
#    'id': 42,
#    'iscrowd': 0,
#    'area': 900},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [965, 333, 31, 30],
#    'id': 43,
#    'iscrowd': 0,
#    'area': 930},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [945, 321, 24, 24],
#    'id': 44,
#    'iscrowd': 0,
#    'area': 576},
#   {'image_id': 45,
#    'category_id': 8,
#    'bbox': [983, 318, 21, 24],
#    'id': 45,
#    'iscrowd': 0,
#    'area': 504},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [966, 315, 24, 22],
#    'id': 46,
#    'iscrowd': 0,
#    'area': 528},
#   {'image_id': 45,
#    'category_id': 11,
#    'bbox': [941, 303, 46, 24],
#    'id': 47,
#    'iscrowd': 0,
#    'area': 1104},
#   {'image_id': 45,
#    'category_id': 10,
#    'bbox': [999, 303, 35, 32],
#    'id': 48,
#    'iscrowd': 0,
#    'area': 1120},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [988, 296, 21, 20],
#    'id': 49,
#    'iscrowd': 0,
#    'area': 420},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1019, 292, 22, 16],
#    'id': 50,
#    'iscrowd': 0,
#    'area': 352},
#   {'image_id': 45,
#    'category_id': 10,
#    'bbox': [1023, 283, 23, 19],
#    'id': 51,
#    'iscrowd': 0,
#    'area': 437},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1037, 278, 19, 18],
#    'id': 52,
#    'iscrowd': 0,
#    'area': 342},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1063, 271, 20, 17],
#    'id': 53,
#    'iscrowd': 0,
#    'area': 340},
#   {'image_id': 45,
#    'category_id': 11,
#    'bbox': [1077, 253, 28, 24],
#    'id': 54,
#    'iscrowd': 0,
#    'area': 672},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1114, 260, 17, 16],
#    'id': 55,
#    'iscrowd': 0,
#    'area': 272},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1109, 251, 13, 18],
#    'id': 56,
#    'iscrowd': 0,
#    'area': 234},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1137, 247, 27, 17],
#    'id': 57,
#    'iscrowd': 0,
#    'area': 459},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1180, 252, 16, 15],
#    'id': 58,
#    'iscrowd': 0,
#    'area': 240},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1190, 246, 18, 15],
#    'id': 59,
#    'iscrowd': 0,
#    'area': 270},
#   {'image_id': 45,
#    'category_id': 11,
#    'bbox': [1160, 217, 29, 15],
#    'id': 60,
#    'iscrowd': 0,
#    'area': 435},
#   {'image_id': 45,
#    'category_id': 5,
#    'bbox': [1206, 217, 14, 11],
#    'id': 61,
#    'iscrowd': 0,
#    'area': 154},
#   {'image_id': 45,
#    'category_id': 4,
#    'bbox': [1191, 235, 34, 12],
#    'id': 62,
#    'iscrowd': 0,
#    'area': 408},
#   {'image_id': 45,
#    'category_id': 4,
#    'bbox': [1206, 226, 32, 11],
#    'id': 63,
#    'iscrowd': 0,
#    'area': 352},
#   {'image_id': 45,
#    'category_id': 4,
#    'bbox': [1233, 185, 65, 37],
#    'id': 64,
#    'iscrowd': 0,
#    'area': 2405},
#   {'image_id': 45,
#    'category_id': 4,
#    'bbox': [795, 201, 198, 42],
#    'id': 65,
#    'iscrowd': 0,
#    'area': 8316},
#   {'image_id': 46,
#    'category_id': 5,
#    'bbox': [874, 633, 162, 190],
#    'id': 0,
#    'iscrowd': 0,
#    'area': 30780},
#   {'image_id': 46,
#    'category_id': 5,
#    'bbox': [785, 883, 206, 196],
#    'id': 1,
#    'iscrowd': 0,
#    'area': 40376},
#   {'image_id': 46,
#    'category_id': 3,
#    'bbox': [213, 799, 98, 87],
#    'id': 2,
#    'iscrowd': 0,
#    'area': 8526},
#   {'image_id': 46,
#    'category_id': 1,
#    'bbox': [225, 797, 58, 68],
#    'id': 3,
#    'iscrowd': 0,
#    'area': 3944},
#   {'image_id': 46,
#    'category_id': 6,
#    'bbox': [0, 688, 107, 61],
#    'id': 4,
#    'iscrowd': 0,
#    'area': 6527},
#   {'image_id': 46,
#    'category_id': 1,
#    'bbox': [15, 677, 51, 74],
#    'id': 5,
#    'iscrowd': 0,
#    'area': 3774},
#   {'image_id': 46,
#    'category_id': 6,
#    'bbox': [313, 406, 71, 57],
#    'id': 6,
#    'iscrowd': 0,
#    'area': 4047},
#   {'image_id': 46,
#    'category_id': 1,
#    'bbox': [319, 391, 45, 63],
#    'id': 7,
#    'iscrowd': 0,
#    'area': 2835},
#   {'image_id': 46,
#    'category_id': 1,
#    'bbox': [351, 408, 32, 46],
#    'id': 8,
#    'iscrowd': 0,
#    'area': 1472},
#   {'image_id': 46,
#    'category_id': 6,
#    'bbox': [377, 319, 64, 54],
#    'id': 9,
#    'iscrowd': 0,
#    'area': 3456},
#   {'image_id': 46,
#    'category_id': 1,
#    'bbox': [385, 307, 37, 56],
#    'id': 10,
#    'iscrowd': 0,
#    'area': 2072},
#   {'image_id': 46,
#    'category_id': 1,
#    'bbox': [403, 314, 30, 50],
#    'id': 11,
#    'iscrowd': 0,
#    'area': 1500},
#   {'image_id': 46,
#    'category_id': 6,
#    'bbox': [453, 307, 64, 54],
#    'id': 12,
#    'iscrowd': 0,
#    'area': 3456},
#   {'image_id': 46,
#    'category_id': 1,
#    'bbox': [461, 295, 40, 51],
#    'id': 13,
#    'iscrowd': 0,
#    'area': 2040},
#   {'image_id': 46,
#    'category_id': 5,
#    'bbox': [556, 165, 159, 94],
#    'id': 14,
#    'iscrowd': 0,
#    'area': 14946},
#   {'image_id': 46,
#    'category_id': 5,
#    'bbox': [307, 84, 134, 96],
#    'id': 15,
#    'iscrowd': 0,
#    'area': 12864},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1724, 456, 44, 39],
#    'id': 0,
#    'iscrowd': 0,
#    'area': 1716},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1676, 386, 33, 27],
#    'id': 1,
#    'iscrowd': 0,
#    'area': 891},
#   {'image_id': 47,
#    'category_id': 10,
#    'bbox': [1766, 350, 29, 28],
#    'id': 2,
#    'iscrowd': 0,
#    'area': 812},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1761, 325, 27, 21],
#    'id': 3,
#    'iscrowd': 0,
#    'area': 567},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1696, 311, 26, 21],
#    'id': 4,
#    'iscrowd': 0,
#    'area': 546},
#   {'image_id': 47,
#    'category_id': 11,
#    'bbox': [1726, 287, 34, 38],
#    'id': 5,
#    'iscrowd': 0,
#    'area': 1292},
#   {'image_id': 47,
#    'category_id': 2,
#    'bbox': [1798, 295, 31, 32],
#    'id': 6,
#    'iscrowd': 0,
#    'area': 992},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1806, 272, 22, 17],
#    'id': 7,
#    'iscrowd': 0,
#    'area': 374},
#   {'image_id': 47,
#    'category_id': 4,
#    'bbox': [1686, 147, 165, 55],
#    'id': 8,
#    'iscrowd': 0,
#    'area': 9075},
#   {'image_id': 47,
#    'category_id': 8,
#    'bbox': [1889, 375, 19, 21],
#    'id': 9,
#    'iscrowd': 0,
#    'area': 399},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1777, 253, 19, 15],
#    'id': 10,
#    'iscrowd': 0,
#    'area': 285},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1808, 242, 18, 13],
#    'id': 11,
#    'iscrowd': 0,
#    'area': 234},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1791, 230, 16, 11],
#    'id': 12,
#    'iscrowd': 0,
#    'area': 176},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1766, 224, 16, 12],
#    'id': 13,
#    'iscrowd': 0,
#    'area': 192},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1780, 203, 12, 9],
#    'id': 14,
#    'iscrowd': 0,
#    'area': 108},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1814, 204, 13, 9],
#    'id': 15,
#    'iscrowd': 0,
#    'area': 117},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1807, 219, 15, 10],
#    'id': 16,
#    'iscrowd': 0,
#    'area': 150},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1841, 219, 14, 11],
#    'id': 17,
#    'iscrowd': 0,
#    'area': 154},
#   {'image_id': 47,
#    'category_id': 10,
#    'bbox': [1794, 211, 12, 12],
#    'id': 18,
#    'iscrowd': 0,
#    'area': 144},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [439, 974, 204, 105],
#    'id': 19,
#    'iscrowd': 0,
#    'area': 21420},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [17, 844, 246, 146],
#    'id': 20,
#    'iscrowd': 0,
#    'area': 35916},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [177, 874, 214, 145],
#    'id': 21,
#    'iscrowd': 0,
#    'area': 31030},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [674, 824, 161, 140],
#    'id': 22,
#    'iscrowd': 0,
#    'area': 22540},
#   {'image_id': 47,
#    'category_id': 10,
#    'bbox': [490, 811, 169, 149],
#    'id': 23,
#    'iscrowd': 0,
#    'area': 25181},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [429, 762, 173, 112],
#    'id': 24,
#    'iscrowd': 0,
#    'area': 19376},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [352, 730, 141, 100],
#    'id': 25,
#    'iscrowd': 0,
#    'area': 14100},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [799, 736, 146, 122],
#    'id': 26,
#    'iscrowd': 0,
#    'area': 17812},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [648, 747, 139, 105],
#    'id': 27,
#    'iscrowd': 0,
#    'area': 14595},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [616, 682, 130, 88],
#    'id': 28,
#    'iscrowd': 0,
#    'area': 11440},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [554, 653, 130, 82],
#    'id': 29,
#    'iscrowd': 0,
#    'area': 10660},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [773, 672, 120, 94],
#    'id': 30,
#    'iscrowd': 0,
#    'area': 11280},
#   {'image_id': 47,
#    'category_id': 10,
#    'bbox': [879, 616, 99, 86],
#    'id': 31,
#    'iscrowd': 0,
#    'area': 8514},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [936, 684, 110, 84],
#    'id': 32,
#    'iscrowd': 0,
#    'area': 9240},
#   {'image_id': 47,
#    'category_id': 10,
#    'bbox': [769, 592, 121, 102],
#    'id': 33,
#    'iscrowd': 0,
#    'area': 12342},
#   {'image_id': 47,
#    'category_id': 10,
#    'bbox': [695, 583, 98, 81],
#    'id': 34,
#    'iscrowd': 0,
#    'area': 7938},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1016, 627, 91, 70],
#    'id': 35,
#    'iscrowd': 0,
#    'area': 6370},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [964, 592, 88, 63],
#    'id': 36,
#    'iscrowd': 0,
#    'area': 5544},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [883, 574, 89, 60],
#    'id': 37,
#    'iscrowd': 0,
#    'area': 5340},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [835, 547, 86, 54],
#    'id': 38,
#    'iscrowd': 0,
#    'area': 4644},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [842, 502, 70, 49],
#    'id': 39,
#    'iscrowd': 0,
#    'area': 3430},
#   {'image_id': 47,
#    'category_id': 10,
#    'bbox': [1079, 575, 84, 79],
#    'id': 40,
#    'iscrowd': 0,
#    'area': 6636},
#   {'image_id': 47,
#    'category_id': 10,
#    'bbox': [962, 523, 76, 70],
#    'id': 41,
#    'iscrowd': 0,
#    'area': 5320},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [904, 514, 82, 54],
#    'id': 42,
#    'iscrowd': 0,
#    'area': 4428},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [962, 455, 61, 47],
#    'id': 43,
#    'iscrowd': 0,
#    'area': 2867},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [981, 484, 68, 46],
#    'id': 44,
#    'iscrowd': 0,
#    'area': 3128},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1027, 508, 67, 48],
#    'id': 45,
#    'iscrowd': 0,
#    'area': 3216},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1051, 539, 73, 56],
#    'id': 46,
#    'iscrowd': 0,
#    'area': 4088},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1157, 560, 76, 57],
#    'id': 47,
#    'iscrowd': 0,
#    'area': 4332},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1205, 529, 69, 50],
#    'id': 48,
#    'iscrowd': 0,
#    'area': 3450},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1112, 510, 72, 49],
#    'id': 49,
#    'iscrowd': 0,
#    'area': 3528},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1046, 456, 68, 45],
#    'id': 50,
#    'iscrowd': 0,
#    'area': 3060},
#   {'image_id': 47,
#    'category_id': 10,
#    'bbox': [1090, 470, 61, 58],
#    'id': 51,
#    'iscrowd': 0,
#    'area': 3538},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1099, 436, 58, 38],
#    'id': 52,
#    'iscrowd': 0,
#    'area': 2204},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1130, 457, 51, 42],
#    'id': 53,
#    'iscrowd': 0,
#    'area': 2142},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1164, 480, 59, 45],
#    'id': 54,
#    'iscrowd': 0,
#    'area': 2655},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1245, 495, 65, 48],
#    'id': 55,
#    'iscrowd': 0,
#    'area': 3120},
#   {'image_id': 47,
#    'category_id': 5,
#    'bbox': [1212, 460, 57, 40],
#    'id': 56,
#    'iscrowd': 0,
#    'area': 2280},
#   ...],
#  'categories': [{'id': 1, 'name': '1', 'supercategory': '1'},
#   {'id': 2, 'name': '2', 'supercategory': '2'},
#   {'id': 3, 'name': '3', 'supercategory': '3'},
#   {'id': 4, 'name': '4', 'supercategory': '4'},
#   {'id': 5, 'name': '5', 'supercategory': '5'},
#   {'id': 6, 'name': '6', 'supercategory': '6'},
#   {'id': 7, 'name': '7', 'supercategory': '7'},
#   {'id': 8, 'name': '8', 'supercategory': '8'},
#   {'id': 9, 'name': '9', 'supercategory': '9'},
#   {'id': 10, 'name': '10', 'supercategory': '10'},
#   {'id': 11, 'name': '11', 'supercategory': '11'}]}

# %%
data.keys()
# Out:
# dict_keys(['images', 'annotations', 'categories'])

# %%
data['images'][0]#['file_name']
# Out:
# {'file_name': '0000002_00005_d_0000014.jpg',
#  'height': 540,
#  'width': 960,
#  'id': 0}

# %%
len(data['images'])
# Out:
# 500

# %%
len(data['annotations'])
# Out:
# 8896

# %%
data['annotations'][0]
# Out:
# {'image_id': 0,
#  'category_id': 4,
#  'bbox': [405, 118, 267, 72],
#  'id': 0,
#  'iscrowd': 0,
#  'area': 19224}

# %%
data['annotations'][1]
# Out:
# {'image_id': 0,
#  'category_id': 4,
#  'bbox': [254, 21, 121, 130],
#  'id': 1,
#  'iscrowd': 0,
#  'area': 15730}

# %%
def count(data, class_id):
#     count = 0
#     for annot in data:
#         if annot['category_id'] == class_id:
#             count += 1
    
    
    
    
    return len([x for x in data if x['category_id'] == class_id])

# %%
classes = {}

for x in data['categories']:
#     print(categories['id'])
    classes[x['id']] = count(data['annotations'], x['id'])

# %%
{1: "quhjhbx", 5: 'aldjcv'}
# Out:
# {1: 'quhjhbx', 5: 'aldjcv'}

# %%
classes = {x['id']: count(data['annotations'], x['id']) for x in data['categories']}

# %%
classes = {x['id']: len([y for y in data['annotations'] if y['category_id'] == x['id']]) for x in data['categories']}

# %%
classes
# Out:
# {1: 390,
#  2: 242,
#  3: 136,
#  4: 191,
#  5: 5703,
#  6: 646,
#  7: 63,
#  8: 131,
#  9: 24,
#  10: 803,
#  11: 567}

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(classes.keys(), classes.values());

# %%
classes
# Out:
# {1: 390,
#  2: 242,
#  3: 136,
#  4: 191,
#  5: 5703,
#  6: 646,
#  7: 63,
#  8: 131,
#  9: 24,
#  10: 803,
#  11: 567}

# %%
data['categories']
# Out:
# [{'id': 1, 'name': '1', 'supercategory': '1'},
#  {'id': 2, 'name': '2', 'supercategory': '2'},
#  {'id': 3, 'name': '3', 'supercategory': '3'},
#  {'id': 4, 'name': '4', 'supercategory': '4'},
#  {'id': 5, 'name': '5', 'supercategory': '5'},
#  {'id': 6, 'name': '6', 'supercategory': '6'},
#  {'id': 7, 'name': '7', 'supercategory': '7'},
#  {'id': 8, 'name': '8', 'supercategory': '8'},
#  {'id': 9, 'name': '9', 'supercategory': '9'},
#  {'id': 10, 'name': '10', 'supercategory': '10'},
#  {'id': 11, 'name': '11', 'supercategory': '11'}]
